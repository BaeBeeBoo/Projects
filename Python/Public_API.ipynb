# %%
import requests

url = "https://api.sampleapis.com/switch/games"
resp = requests.get(url)

#check status code
resp.status_code
# Out:
# 200

# %%
import time

switch_games = []

for i in range(20):
    url = f"https://api.sampleapis.com/switch/games={i+1}"
    if resp.status_code == 200:
        json_data = resp.json()
        name.append(json_data[i]["name"]),
        genre.append(json_data[i]["genre"]),
        developers.append(json_data[i]["developers"]),
        publishers.append(json_data[i]["publishers"])
    else:
        name.append(json_data["error"])
        genre.append(json_data["error"])
        developers.append(json_data["error"])
        publishers.append(json_data["error"])

time.sleep(1)

# %%
import pandas as pd

data = {"Name": name, "Genre": genre, "Developers": developers, "Publishers": publishers}
games = pd.DataFrame.from_dict(data, orient='index')
games = games.transpose()
games
# Out:
#                                  Name                             Genre  \
# 0                #Breakforcist Battle                           [Party]
# 1                #Breakforcist Battle                           [Party]
# 2                     #KillAllZombies  [Survival, third-person shooter]
# 3                         #RaceDieRun                          [Racing]
# 4                  'n Velore Verstand                       [Adventure]
# ..                                ...                               ...
# 76  2064: Read Only Memories Integral                       [Adventure]
# 77                               20XX                      [Platformer]
# 78            30-in-1 Game Collection                          [Arcade]
# 79           36 Fragments of Midnight                      [Platformer]
# 80                        3D MiniGolf                          [Sports]
#
#                Developers                             Publishers
# 0     [Lucid Sheep Games]                    [Lucid Sheep Games]
# 1     [Lucid Sheep Games]                          [Beatshapers]
# 2           [Beatshapers]                           [QubicGames]
# 3            [QubicGames]                      [Skobbejak Games]
# 4       [Skobbejak Games]                             [Nintendo]
# ..                    ...                                    ...
# 76              [MidBoss]                  [Batterystaple Games]
# 77  [Batterystaple Games]                        [Digital Bards]
# 78        [Digital Bards]  [JP: Rainy Frog, WW: Ratalaika Games]
# 79         [Petite Games]                             [Joindots]
# 80             [Joindots]                                   None
#
# [81 rows x 4 columns]
